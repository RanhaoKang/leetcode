# %% [markdown]
# # 问题描述
# Given a binary search tree and the lowest and highest boundaries as L and R, trim the tree so that all its elements lies in [L, R] (R >= L). You might need to change the root of the tree, so the result should return the new root of the trimmed binary search tree.
#
# **Example 1:**
# ```
# Input:
#     1
#    / \
#   0   2
#
#   L = 1
#   R = 2
#
# Output:
#     1
#       \
#        2
# ```
# **Example 2:**
# ```
# Input:
#     3
#    / \
#   0   4
#    \
#     2
#    /
#   1
#
#   L = 1
#   R = 3
#
# Output:
#       3
#      /
#    2
#   /
#  1
# ```

# %% [markdown]
# # 个人Solutions

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

# 搜索树从根搜索简单, 所以走的是先序遍历, 然而这里要保存根, 就会麻烦一些
# 一棵子树的根节点的两个最值在叶节点, 所以不能根据根节点直接判断删除与否

class Solution:
    def _trimBST(self, root, L, R):
        """
        :type root: TreeNode
        :type L: int
        :type R: int
        :rtype: TreeNode
        """
        if root is None: return
        
        if root.val < L:
            self._trimBST(root.right, L, R) 
        elif root.val > R:
            self._trimBST(root.left, L, R)
        else: # root is in (L,R)
            # root is OK, so we keep it.
            self.root = root
            # and then we start to trim its branches and leaves. we pass a "parent" node to help to delete the node.
            self.__trimBST(root.left, root, 'L', L, R)
            self.__trimBST(root.right, root, 'R', L, R)
            
    def __trimBST(self, node, parent, f, L, R):
        if node is None: return
        
        # root is minimum
        if node.val < L:
            if f == 'L':
                parent.left = node.right
            else:
                parent.right = node.right
            self.__trimBST(node.right, parent, f, L, R)
        elif node.val > R:
            if f == 'L':
                parent.left = node.left
            else:
                parent.right = node.left
            self.__trimBST(node.left, parent, f, L, R)
        else: # node.val == L == R
            self.__trimBST(node.left, node, 'L', L, R)
            self.__trimBST(node.right, node, 'R', L, R)
    
    def trimBST(self, root, L, R):
        """
        :type root: TreeNode
        :type L: int
        :type R: int
        :rtype: TreeNode
        """
        self._trimBST(root, L, R)
        return self.root

# %% [markdown]
# # Solution&Discuss精选

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution(object):
    def trimBST(self, root, L, R):
        # 每一层的Condition
        if not root: return root
        if root.val > R: return self.trimBST(root.left, L, R)
        if root.val < L: return self.trimBST(root.right, L, R)

        # 再区间内，正常的Recursion
        root.left = self.trimBST(root.left, L, R)
        root.right = self.trimBST(root.right, L, R)
        
        # 返回给parent一个区间调整完以后的subtree
        return root
