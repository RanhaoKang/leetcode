# %% [markdown]
# [641. Design Circular Deque](https://leetcode.com/problems/design-circular-deque/)

# %% [markdown]
# 参考Programming in Lua

# %%
class MyCircularDeque:

    def __init__(self, k: int):
        """
        Initialize your data structure here. Set the size of the deque to be k.
        """
        self._first, self._last, self._k = 0, -1, k
        self._list = [-1] * k
        

    def insertFront(self, value: int) -> bool:
        """
        Adds an item at the front of Deque. Return true if the operation is successful.
        """
        if self.isFull():
            return False
        self._first -= 1
        self._list[self._first] = value
        return True
        

    def insertLast(self, value: int) -> bool:
        """
        Adds an item at the rear of Deque. Return true if the operation is successful.
        """
        if self.isFull():
            return False
        self._last += 1
        self._list[self._last] = value
        return True
        

    def deleteFront(self) -> bool:
        """
        Deletes an item from the front of Deque. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        self._list[self._first] = -1
        self._first += 1
        return True
        

    def deleteLast(self) -> bool:
        """
        Deletes an item from the rear of Deque. Return true if the operation is successful.
        """
        if self.isEmpty():
            return False
        self._list[self._last] = -1
        self._last -= 1
        return True
        

    def getFront(self) -> int:
        """
        Get the front item from the deque.
        """
        return self._list[self._first]
        

    def getRear(self) -> int:
        """
        Get the last item from the deque.
        """
        return self._list[self._last]
        

    def isEmpty(self) -> bool:
        """
        Checks whether the circular deque is empty or not.
        """
        return self._first > self._last
        

    def isFull(self) -> bool:
        """
        Checks whether the circular deque is full or not.
        """
        return self._last - self._first + 1 >= self._k
        


# Your MyCircularDeque object will be instantiated and called as such:
# obj = MyCircularDeque(k)
# param_1 = obj.insertFront(value)
# param_2 = obj.insertLast(value)
# param_3 = obj.deleteFront()
# param_4 = obj.deleteLast()
# param_5 = obj.getFront()
# param_6 = obj.getRear()
# param_7 = obj.isEmpty()
# param_8 = obj.isFull()

# %%
circularDeque = MyCircularDeque(3)
res = circularDeque.insertLast(1)
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.insertLast(2)
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.insertFront(3)
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.insertFront(4)
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.getRear()
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.isFull()
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.deleteLast()
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.insertFront(4)
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
res = circularDeque.getFront()
print(f'res={res}, first={circularDeque._first}, last={circularDeque._last}, list={circularDeque._list}')
# Out:
# res=True, first=0, last=0, list=[1, -1, -1]
# res=True, first=0, last=1, list=[1, 2, -1]
# res=True, first=-1, last=1, list=[1, 2, 3]
# res=False, first=-1, last=1, list=[1, 2, 3]
# res=2, first=-1, last=1, list=[1, 2, 3]
# res=True, first=-1, last=1, list=[1, 2, 3]
# res=True, first=-1, last=0, list=[1, -1, 3]
# res=True, first=-2, last=0, list=[1, 4, 3]
# res=4, first=-2, last=0, list=[1, 4, 3]

# %%
circularDeque.insertLast(1);			// return true
circularDeque.insertLast(2);			// return true
circularDeque.insertFront(3);			// return true
circularDeque.insertFront(4);			// return false, the queue is full
circularDeque.getRear();  			// return 2
circularDeque.isFull();				// return true
circularDeque.deleteLast();			// return true
circularDeque.insertFront(4);			// return true
circularDeque.getFront();			// return 4
